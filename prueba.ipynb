# %% [markdown]
# Esto es una prueba:
# \begin{equation}
#     \int_a^b f'(x)dx = f(b) - f(a)
# \end{equation}

# %%
import numpy as np

def punto_medio(f, a, b, N):
    h = (b-a)/N
    return h * sum( f(a +(i+0.5)*h) for i in range N)

def trapecio():
     h = (b-a)/N
    return h * sum( f(a +(i+0.5)*h) for i in range N)
